# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.decomposition import PCA
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import Imputer, OneHotEncoder
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
# %matplotlib inline

# %%
data = pd.read_csv('train.txt', usecols=range(1, 15), names=('x{}'.format(i) for i in range(14)), skiprows=1)
test = pd.read_csv('test.txt', usecols=range(1, 15), names=('x{}'.format(i) for i in range(14)), skiprows=1)
labels = pd.read_csv('target_train.txt')
labels = labels[1:]
labels = np.array(labels['target'])

# %%
print (type(enumerate(np.array(data.head(1))[0])))
text_feature_indexs = []
for index, value in enumerate(np.array(data.head(1))[0]):
    if not np.isreal(value):
        text_feature_indexs.append(index)
        
print (text_feature_indexs)
# Out:
# <class 'enumerate'>
# [1, 3, 5, 6, 7, 8, 9, 13]

# %%
test.head()
# Out:
#    x0        x1      x2          x3  x4                   x5               x6  \
# 0  28   Private   37821   Assoc-voc  11        Never-married            Sales
# 1  45   Private  228570     HS-grad   9   Married-civ-spouse            Sales
# 2  21   Private  141453     HS-grad   9        Never-married    Other-service
# 3  34   Private   88215     Masters  14   Married-civ-spouse   Prof-specialty
# 4  53   Private   48641        12th   8        Never-married    Other-service
#
#                x7                   x8       x9  x10  x11  x12             x13
# 0       Unmarried                White   Female    0    0   55               ?
# 1            Wife                White   Female    0    0   35   United-States
# 2       Own-child                White   Female    0    0   40   United-States
# 3            Wife   Asian-Pac-Islander   Female    0    0   40           China
# 4   Not-in-family                Other   Female    0    0   35   United-States

# %%
data.head()
# Out:
#    x0                 x1      x2          x3  x4                   x5  \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    x6              x7      x8       x9   x10  x11  x12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174    0   40
# 1     Exec-managerial         Husband   White     Male     0    0   13
# 2   Handlers-cleaners   Not-in-family   White     Male     0    0   40
# 3   Handlers-cleaners         Husband   Black     Male     0    0   40
# 4      Prof-specialty            Wife   Black   Female     0    0   40
#
#               x13
# 0   United-States
# 1   United-States
# 2   United-States
# 3   United-States
# 4            Cuba

# %%
common_data = data
common_data = common_data.append(test)

# %%
def categorial_string_to_numbers(values):
    uniq_values = set(values)
    values_to_num = dict(zip(values, range(len(values))[::-1]))
    return map(lambda x: values_to_num[x], values)

# %%
for i in text_feature_indexs:
    common_data['x{}'.format(i)] = list(categorial_string_to_numbers(common_data['x{}'.format(i)]))

# %%
pd.DataFrame(common_data)
# Out:
#       x0  x1      x2  x3  x4   x5   x6  x7  x8  x9    x10   x11  x12   x13
# 0     39  11   77516  22  13    1    1   5   0   1   2174     0   40     0
# 1     50  10   83311  22  13    0    0   3   0   1      0     0   13     0
# 2     38   1  215646   0   9   11    9   5   0   1      0     0   40     0
# 3     53   1  234721  38   7    0    9   3  19   1      0     0   40     0
# 4     28   1  338409  22  13    0   12   0  19   0      0     0   40   653
# 5     37   1  284582   6  14    0    0   0   0   0      0     0   40     0
# 6     49   1  160187  59   5  104   16   5  19   0      0     0   16   331
# 7     52  10  209642   0   9    0    0   3   0   1      0     0   45     0
# 8     31   1   45781   6  14    1   12   5   0   0  14084     0   50     0
# 9     42   1  159449  22  13    0    0   3   0   1   5178     0   40     0
# 10    37   1  280464   5  10    0    0   3  19   1      0     0   80     0
# 9994  22   1  310152   5  10    1    5   5   0   1      0     0   40     0
# 9995  27   1  257302   4  12    0    4   0   0   0      0     0   38     0
# 9996  40   1  154374   0   9    0    3   3   0   1      0     0   40     0
# 9997  58   1  151910   0   9    2    1   2   0   0      0     0   40     0
# 9998  22   1  201490   0   9    1    1   1   0   1      0     0   20     0
# 9999  52   0  287927   0   9    0    0   0   0   0  15024     0   40     0
#
# [32561 rows x 14 columns]

# %%
common_data_ohe = OneHotEncoder(categorical_features=text_feature_indexs).fit_transform(common_data)

# %%
common_data_ohe
# Out:
# <32561x108 sparse matrix of type '<class 'numpy.float64'>'
# 	with 394963 stored elements in COOrdinate format>

# %%
common_data_dense = common_data_ohe.todense()

# %%
common_data_dense.shape
# Out:
# (32561, 108)

# %%
X_train = common_data_dense[:22561]
X_test = common_data_dense[22561:32561]
y_train = labels

# %%
X_train.shape
# Out:
# (22561, 108)

# %% [markdown]
# # Обучаем модельки

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test)

param = {'objective':'multi:softmax', 'bst:max_depth':3, 'bst:eta':0.1, 'silent':1, 'nthread':4, 'num_class':2}
plst = param.items()

# %%
def xgboost_accuracy_scores(sample, true_targets): 
    return np.array([accuracy_score(true_targets,
                                    model.predict(sample, ntree_limit=n + 1)) 
                     for n in range(num_boost_round)])

# %%
# %%time
num_boost_round = 100
model = xgb.train(plst, dtrain, num_boost_round=num_boost_round)
# Out:
# CPU times: user 8.23 s, sys: 64 ms, total: 8.29 s
# Wall time: 2.17 s

# %%
xgb_scores_train = xgboost_accuracy_scores(dtrain, y_train)

plt.figure(figsize=(15, 6))
plt.plot(np.arange(len(xgb_scores_train)) + 1, xgb_scores_train, label='xgb train')
plt.legend()
plt.show()

# %%
fi = model.get_fscore()
print(fi)
# Out:
# {'f2': 18, 'f103': 60, 'f68': 1, 'f36': 6, 'f51': 3, 'f75': 5, 'f49': 1, 'f11': 2, 'f37': 2, 'f4': 3, 'f33': 1, 'f28': 1, 'f12': 21, 'f17': 8, 'f32': 24, 'f26': 5, 'f29': 1, 'f106': 199, 'f9': 6, 'f25': 90, 'f0': 11, 'f62': 6, 'f57': 6, 'f13': 3, 'f30': 1, 'f107': 119, 'f40': 16, 'f3': 3, 'f34': 9, 'f44': 22, 'f50': 2, 'f1': 4, 'f104': 101, 'f31': 6, 'f35': 15, 'f47': 29, 'f41': 19, 'f6': 10, 'f39': 1, 'f60': 2, 'f105': 216, 'f38': 9, 'f52': 5, 'f102': 209, 'f58': 9, 'f53': 6, 'f48': 11}

# %%
# %%time
num_boost_round = 1000
model = xgb.train(plst, dtrain, num_boost_round=num_boost_round)
# Out:
# CPU times: user 1min 24s, sys: 884 ms, total: 1min 24s
# Wall time: 23.3 s

# %%
ans = model.predict(dtest, )

with open ('resultsV3', 'w') as f:
    f.write('id,target\n')
    for i in range(10000):
        f.write(str(22562 + i) + ',' + str(int(ans[i])) + '\n')

# %%
sum(ans)/len(ans)
# Out:
# 0.20660000000000001
